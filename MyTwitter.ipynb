# %%
# !pip install tweepy

# %%
# Team 1-3
import tweepy  # https://docs.tweepy.org/en/v3.6.0/api.html
CONSUMER_KEY = 'MbhA6iSZflOyYErveZzuNosE4'
CONSUMER_SECRET ='zvz5i6WBvS81EGkYQKMArXmnvL1vaVXXAZfskFclAeUgrU2twR'
OAUTH_TOKEN = '571213367-umrVxIxuWiE1uzGOw279gdsvecNQBXdab7CfqZuy'
OAUTH_TOKEN_SECRET = 'BI7pACPjUhZJtNNFJOZ1PLV2lflZzzEA16lLp7oFWsDvU'
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)

# %%
try:
    redirect_url = auth.get_authorization_url()
except tweepy.TweepError:
    print('Error! Failed to get request token.')

# %%
api = tweepy.API(auth)

# %%
tweets = api.user_timeline("TheSIAMNews")

# %%
json_tweets = [tweet._json for tweet in tweets]

# %%
import os
import json
def appendTweets(filename, tweets_to_write):
    if os.path.exists(filename):
        with open(filename, 'r+') as file:
            # First we load existing data into a dict.
            file_data = json.load(file)
            # Join new_dat3a with file_data
            #for t in tweets_to_write:
              ##  file_data += t
            file_data += tweets_to_write
            # Sets file's current position at offset.
            file.seek(0)
            # convert back to json.
            json.dump(file_data, file, indent = 1)
    else:
        with open(filename, 'w+') as file:
            # convert back to json.
            json.dump(tweets_to_write, file, indent = 1)

# %%
filename = 'my_precious_tweets_on_%s.json'%'test'
appendTweets(filename,json_tweets)

# %%
import pandas as pd
data = pd.DataFrame(json_tweets)

# %%
data.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Tue Jun 29 15:04:30 +0000 2021  1409890525319155712  1409890525319155712
# 1  Mon Jun 28 16:01:16 +0000 2021  1409542425496932354  1409542425496932354
# 2  Fri Jun 25 16:01:13 +0000 2021  1408455248625258496  1408455248625258496
# 3  Fri Jun 25 13:21:44 +0000 2021  1408415114248785931  1408415114248785931
# 4  Thu Jun 24 15:48:05 +0000 2021  1408089555299975169  1408089555299975169
#
#                                                 text  truncated  \
# 0  The Seminar in the Analysis and Methods of PDE...       True
# 1  In SIAM News, Ronald K. Pearson reflects on th...       True
# 2  The National Academy of Sciences (@theNAScienc...       True
# 3  SIAM Conference on Imaging Science (IS22) Call...      False
# 4  RT @UniofReading: UoR mathematician and comput...      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...
